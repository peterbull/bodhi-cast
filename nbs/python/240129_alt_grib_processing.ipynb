# %%
import requests
import xarray as xr
from pathlib import Path
import pytz
import datetime
import cfgrib
import tempfile

# %%
import pygrib

# %%
date = '20240128' # change this to get current date
url = f"https://nomads.ncep.noaa.gov/pub/data/nccf/com/gens/prod/gefs.{date}/00/wave/gridded/"
target = "gefs.wave.t00z.mean.global.0p25.f045.grib2"

def write_response(url, target, data='./data/'):
    response = requests.get(f'{url}/{target}')
    
    if response.status_code == 200:
        with open(f'{data}/{target}', 'wb') as f:
            f.write(response.content)
        print(f"{target} written successfully")
    else:
        print(f"Error: {response.status_code}")
write_response(url, target)
# Out:
# gefs.wave.t00z.mean.global.0p25.f045.grib2 written successfully

# %%
current_time = datetime.datetime.now()
utc_time = current_time.astimezone(pytz.utc)

# %%
utc_time
# Out:
# datetime.datetime(2024, 1, 29, 12, 13, 18, 355672, tzinfo=<UTC>)

# %%
grbs = pygrib.open('./data/gefs.wave.t00z.mean.global.0p25.f045.grib2')

# %%
grbs.seek(1)
for grb in grbs:
    print(grb)
# Out:
# 2:Primary wave mean period:s (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 3:Primary wave direction:Degree true (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 4:Significant height of wind waves:m (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 5:Mean period of wind waves:s (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 6:Direction of wind waves:Degree true (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 7:Wind speed:m s**-1 (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 8:Wind direction:Degree true (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 9:Significant height of swell waves:m (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 10:Significant height of swell waves:m (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 11:Mean period of swell waves:s (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean
# 12:Mean period of swell waves:s (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean

# %%
grb = grbs.select(name="Maximum temperature")[0]

# %%
"""
A set of my pandas-like wrappers around pygrib.open() and pygrib.select() functionality that I find it bit more
intuitive and useful for my workflow. It also contains a patch to the "GRIB API stepUnits error" when reading gribs 
with stepUnits below 1 hour. 
DEPENDECIES: Numpy, Pandas and of course pygrib (with GRIB API C library available on system!).
Use at your own risk. Any corrections, suggestions, improvements and comments welcome!
Author: Marjan Moderc, Slovenian Environment Agency (ARSO), 2017 (email: marjan.moderc@gov.si)
"""

import os
import pygrib
import numpy as np
import pandas as pd
from collections import Counter
from datetime import datetime, timedelta


def print_grib_content_report(gribfile):
    """
    Function that describes a grib file as an exhaustive pandas dataframes.
    :param gribfile: String representing a path to grib file or a list of grib messages
    :return:
    """

    if isinstance(gribfile, str):
        grbs = open_grib(gribfile)
    else:
        if isinstance(grbfile, list):
            grbs = gribfile
        else:
            grbs = [gribfile]

    df = pd.DataFrame(index=grbs[0].keys())

    for i, grb in enumerate(grbs[:]):
        values = []
        for feature in grb.keys():
            try:
                value = grb[feature]
            except:
                value = None

            if isinstance(value, list) or isinstance(value, np.ndarray):
                # skip np arrays and lists to maintain clarity
                value = None
            values.append(value)

        df[i] = values

    df_same = df[df.apply(pd.Series.nunique, axis=1) == 1]
    df_same = df_same.sort_index()
    df_unique = df[df.apply(pd.Series.nunique, axis=1) > 1].transpose()

    print("GRIB FILE DESCRIPTION:")
    print("***********************************************************")
    print("")
    if isinstance(gribfile, str):
        print("Grib name: {}".format(os.path.abspath(gribfile)))

    if "dataDate" in df.index.tolist() and "dataTime" in df.index.tolist():
        print("Grib date: {} {}".format(grbs[0]["dataDate"], grbs[0]["dataTime"]))

    if "Nx" in df.index.tolist() and "Nx" in df.index.tolist():
        print("Layer size (X x Y): {}x{}".format(grbs[0]["Nx"], grbs[0]["Ny"]))

    print("Number of layers: {}".format(len(grbs)))

    if "name" in df.index.tolist():
        print("Available datasets:")
        for key, value in Counter(df.loc["name", :].values.tolist()).items():
            print("\t{} ({})".format(key, value))
    print("")
    print("")
    print("GENERAL GRIB DATA OVERVIEW:")
    print("")
    print_full_df(df_same.iloc[:, [0]])

    print("")
    print("")
    print("LAYER-SPECIFIC DATA OVERVIEW:")
    print("")
    print_full_df(df_unique)
    print("")
    print("***********************************************************")
    print("")
    print("")


def open_grib(grbs, timestep_interval_mins=60):
    """
    Wrapper function around basic pygrib.open() functionality, patching a GRIB API bug at the time of writing
    this script (early 2017ish), where it seems to lack the decoding ability for stepUnits below 1 hour. At the same time,
    open_grib converts grib object into the list of grib messages on the fly.
    This functions well with a custom filtering (= selecting) function, filter_grib_messages() --> see below
    :param grbs: String pointing to the location of a grib.
    :param timestep_interval_mins: Manual correction attribute for bypassing grib api stepUnits error. Defaults to 60 mins (1H)
    :return:
    """

    if not isinstance(grbs, str):
        raise IOError("Grbs argument has to be a path to the grib file!")

    grbs = pygrib.open(grbs)
    grbs = grbs.select()

    for grb in grbs:
        if timestep_interval_mins < 60:
            grb["stepUnits"] = 0

    # If grib file consists of one grib message only, it returns this one, instead of one-element list.
    if isinstance(grbs, list) and len(grbs) == 1:
        grbs = grbs[0]

    return grbs


def filter_grib_layers(grbs, **grib_layer_filters):
    """
    Replacement of pygrib.select() function that filters a list of grib messages, not a grib object itself. This allows
    for multiple consecutive calls of that function since input and output of this function is both a list (except when
    there is only one grib layer left after filtering.
    :param grbs: List of grib messages
    :param grib_layer_filters: pygrib.select()-style kwargs for selecting data e.g. validityDate = 20170104, shortName="tp" ,...
    :return: List of grib messages that satisfy the criteria
    """

    # Returns grib_objects that meet given selection criteria.
    def passes_filters(grb):
        """
        Helper function for filtering a single grib message. True if passes the filter,
        False if it doesnt satisfy anyone of the given.
        :param grb:
        :return:
        """
        for filter in grib_layer_filters:
            if isinstance(grib_layer_filters[filter], list):
                if grb[filter] not in grib_layer_filters[filter]:
                    return False
            else:
                if grb[filter] != grib_layer_filters[filter]:
                    return False

        return True

    # Filter gribs
    ok = [i for i in grbs if passes_filters(i)]

    print("After filterings still {} grib messages left.".format(len(ok)))

    if isinstance(ok, list) and len(ok) == 1:
        ok = ok[0]

    return ok


def get_grib_layer_simulation_datetime(grb):
    # Helper function to quickly get a simulation time of grib message

    dataTime = str(grb["dataTime"]).zfill(4)
    dataDate = str(grb["dataDate"])
    return datetime.strptime(dataDate + dataTime, "%Y%m%d%H%M")


def get_grib_layer_validity_datetime(grb):
    # Helper function to quickly get a validity time of grib message (=simulation_run_date + forecastingTime)

    return get_grib_layer_simulation_datetime(grb) + timedelta(minutes=int(grb["endStep"]))


def grib_message_to_arrays_raster(grb, nodata_buffer=0.001, nodata=0):
    """
    Function for extraction of values, lats and lons from a single grib message
    :param grb: Grib message. Must be one layer only!
    :param nodata_buffer: Values below this treshold will be rounded to nodata.
            Usefull for erasing numerical rounding errors. Defaults to 0.001
    :param nodata: No data value. Defaults to 0
    :return:
    """
    # Converts single grib layer gribfile into ndarrays of values, lats and lons

    if isinstance(grb, list):
        if len(grb) == 1:
            grb = grb[0]
        else:
            raise IOError(
                "You can only pass a one-layered grib list or a grib message. "
                "You passed a grib with {} layers.".format(len(grb))
            )

    values = grb.values  # read data into np array
    if nodata_buffer:
        values[values < nodata_buffer] = nodata

    lats, lons = grb.latlons()  # read coordinates

    return values, lats, lons


def print_full_df(x):
    # Helper function to allow for full display of pandas dataframe

    pd.set_option("display.max_rows", len(x.index))
    pd.set_option("display.max_columns", len(x.columns))
    print(x)
    pd.reset_option("display.max_rows")
    pd.reset_option("display.max_columns")

# %%
gribfile = './data/gefs.wave.t00z.mean.global.0p25.f045.grib2'

# %%
print_grib_content_report(gribfile)
# Out:
# GRIB FILE DESCRIPTION:
# ***********************************************************
#
# Grib name: /home/peter-legion-wsl2/peter-projects/bodhi-cast/nbs/python/data/gefs.wave.t00z.mean.global.0p25.f045.grib2
# Grib date: 20240128 0
# Number of layers: 12
# Available datasets:
# 	Significant height of combined wind waves and swell (1)
# 	Primary wave mean period (1)
# 	Primary wave direction (1)
# 	Significant height of wind waves (1)
# 	Mean period of wind waves (1)
# 	Direction of wind waves (1)
# 	Wind speed (1)
# 	Wind direction (1)
# 	Significant height of swell waves (2)
# 	Mean period of swell waves (2)
#
#
# GENERAL GRIB DATA OVERVIEW:
#
#                                                                                         0
# GRIBEditionNumber                                                                       2
# NV                                                                                      0
# Ni                                                                                   1440
# Nj                                                                                    721
# PLPresent                                                                               0
# PVPresent                                                                               0
# alternativeRowScanning                                                                  0
# angleDivisor                                                                      1000000
# angleMultiplier                                                                         1
# angleSubdivisions                                                                 1000000
# backgroundProcess                                                                       0
# basicAngleOfTheInitialProductionDomain                                                  0
# binaryScaleFactor                                                                       0
# bitMapIndicator                                                                         0
# bitmapPresent                                                                           1
# bottomLevel                                                                             0
# centre                                                                               kwbc
# centreDescription                                      US National Weather Service - NCEP
# cfName                                                                            unknown
# cfNameECMF                                                                        unknown
# changeDecimalPrecision                                                                  2
# dataDate                                                                         20240128
# dataRepresentationTemplateNumber                                                       40
# dataTime                                                                                0
# datasetForLocal                                                                   unknown
# day                                                                                    28
# decimalPrecision                                                                        2
# decimalScaleFactor                                                                      2
# deleteCalendarId                                                                        0
# deleteLocalDefinition                                                                   0
# deletePV                                                                                1
# derivedForecast                                                                         0
# editionNumber                                                                           2
# endStep                                                                                45
# forecastTime                                                                           45
# genVertHeightCoords                                                                     0
# generatingProcessIdentifier                                                            10
# getNumberOfValues                                                                 1038240
# globalDomain                                                                            g
# grib2LocalSectionPresent                                                                0
# grib2divider                                                                      1000000
# gridDefinitionDescription               Latitude/longitude. Also called equidistant cy...
# gridDefinitionTemplateNumber                                                            0
# gridDescriptionSectionPresent                                                           1
# gridType                                                                       regular_ll
# hour                                                                                    0
# hoursAfterDataCutoff                                                                    0
# iDirectionIncrement                                                                250000
# iDirectionIncrementGiven                                                                1
# iDirectionIncrementInDegrees                                                         0.25
# iScansNegatively                                                                        0
# iScansPositively                                                                        1
# identifier                                                                           GRIB
# ieeeFloats                                                                              1
# ijDirectionIncrementGiven                                                               1
# indicatorOfUnitOfTimeRange                                                              1
# interpretationOfNumberOfPoints                                                          0
# isConstant                                                                            0.0
# isHindcast                                                                              0
# is_aerosol                                                                              0
# is_aerosol_optical                                                                      0
# is_chemical                                                                             0
# is_chemical_distfn                                                                      0
# is_chemical_srcsink                                                                     0
# jDirectionIncrement                                                                250000
# jDirectionIncrementGiven                                                                1
# jDirectionIncrementInDegrees                                                         0.25
# jPointsAreConsecutive                                                                   0
# jScansNegatively                                                                        1
# jScansPositively                                                                        0
# julianDay                                                                       2460337.5
# latitudeOfFirstGridPoint                                                         90000000
# latitudeOfFirstGridPointInDegrees                                                    90.0
# latitudeOfLastGridPoint                                                         -90000000
# latitudeOfLastGridPointInDegrees                                                    -90.0
# lengthOfHeaders                                                                       129
# level                                                                                   0
# levtype                                                                               sfc
# localTablesVersion                                                                      1
# longitudeOfFirstGridPoint                                                               0
# longitudeOfFirstGridPointInDegrees                                                    0.0
# longitudeOfLastGridPoint                                                        359750016
# longitudeOfLastGridPointInDegrees                                              359.750016
# mAngleMultiplier                                                                  1000000
# mBasicAngle                                                                             0
# masterDir                                                    grib2/tables/[tablesVersion]
# md5Section1                                              f17fde634b3da300e48a769c6643dad4
# md5Section3                                              e513ef2d5d1c8b86dc7bd98806c03875
# minute                                                                                  0
# minutesAfterDataCutoff                                                                  0
# missingValue                                                                         9999
# modelName                                                                         unknown
# month                                                                                   1
# nameOfFirstFixedSurface                                           Ground or water surface
# nameOfSecondFixedSurface                                                          Missing
# neitherPresent                                                                          0
# numberOfDataPoints                                                                1038240
# numberOfForecastsInEnsemble                                                            31
# numberOfOctectsForNumberOfPoints                                                        0
# offsetValuesBy                                                                        0.0
# optimizeScaleFactor                                                                     0
# packingType                                                                     grid_jpeg
# pressureUnits                                                                         hPa
# productDefinitionTemplateNumber                                                         2
# productType                                                                       unknown
# productionStatusOfProcessedData                                                         0
# radius                                                                            6371229
# resolutionAndComponentFlags                                                            48
# resolutionAndComponentFlags1                                                            0
# resolutionAndComponentFlags2                                                            0
# resolutionAndComponentFlags6                                                            0
# resolutionAndComponentFlags7                                                            0
# resolutionAndComponentFlags8                                                            0
# scaleFactorOfEarthMajorAxis                                                             0
# scaleFactorOfEarthMinorAxis                                                             0
# scaleFactorOfFirstFixedSurface                                                          0
# scaleFactorOfRadiusOfSphericalEarth                                                     0
# scaleFactorOfSecondFixedSurface                                                         0
# scaleValuesBy                                                                         1.0
# scaledValueOfEarthMajorAxis                                                             0
# scaledValueOfEarthMinorAxis                                                             0
# scaledValueOfFirstFixedSurface                                                          0
# scaledValueOfRadiusOfSphericalEarth                                                     0
# scaledValueOfSecondFixedSurface                                                         0
# scanningMode                                                                            0
# scanningMode5                                                                           0
# scanningMode6                                                                           0
# scanningMode7                                                                           0
# scanningMode8                                                                           0
# second                                                                                  0
# section0Length                                                                         16
# section1Length                                                                         21
# section3Length                                                                         72
# section4Length                                                                         36
# section5Length                                                                         23
# section6Length                                                                     129786
# section8Length                                                                          4
# selectStepTemplateInstant                                                               1
# selectStepTemplateInterval                                                              1
# setCalendarId                                                                           0
# shapeOfTheEarth                                                                         6
# significanceOfReferenceTime                                                             1
# sourceOfGridDefinition                                                                  0
# startStep                                                                              45
# stepRange                                                                              45
# stepType                                                                          instant
# stepTypeInternal                                                                  instant
# stepUnits                                                                               1
# subCentre                                                                               0
# subdivisionsOfBasicAngle                                                                0
# tablesVersion                                                                           2
# tablesVersionLatest                                                                    31
# tablesVersionLatestOfficial                                                            31
# targetCompressionRatio                                                                255
# tempPressureUnits                                                                     hPa
# topLevel                                                                                0
# typeOfCompressionUsed                                                                   0
# typeOfFirstFixedSurface                                                               sfc
# typeOfGeneratingProcess                                                                 4
# typeOfLevel                                                                       surface
# typeOfOriginalFieldValues                                                               0
# typeOfProcessedData                                                                    fc
# typeOfSecondFixedSurface                                                              255
# unitsOfFirstFixedSurface                                                          unknown
# unitsOfSecondFixedSurface                                                         unknown
# uvRelativeToGrid                                                                        0
# validityDate                                                                     20240129
# validityTime                                                                         2100
# year                                                                                 2024
#
#
# LAYER-SPECIFIC DATA OVERVIEW:
#
#    discipline totalLength parameterCategory parameterNumber parameterUnits  \
# 0          10      371158                 0               3              m
# 1          10      504197                 0              11              s
# 2          10      847410                 0              10    Degree true
# 3          10      478577                 0               5              m
# 4          10      613775                 0               6              s
# 5          10      917967                 0               4    Degree true
# 6           0      566937                 2               1          m s-1
# 7           0      891673                 2               0       deg true
# 8          10      461536                 0               8              m
# 9          10      423669                 0               8              m
# 10         10      608747                 0               9              s
# 11         10      690366                 0               9              s
#
#                                         parameterName paramIdECMF paramId  \
# 0   Significant height of combined wind waves and ...      140229  140229
# 1                            Primary wave mean period      260234  260234
# 2                              Primary wave direction      260233  260233
# 3                    Significant height of wind waves      140234  140234
# 4                           Mean period of wind waves      140236  140236
# 5                             Direction of wind waves      260232  260232
# 6                                          Wind speed          10      10
# 7                 Wind direction (from which blowing)        3031    3031
# 8                   Significant height of swell waves        3105    3105
# 9                   Significant height of swell waves        3105    3105
# 10                         Mean period of swell waves        3106    3106
# 11                         Mean period of swell waves        3106    3106
#
#    shortNameECMF shortName    unitsECMF        units  \
# 0            swh       swh            m            m
# 1          perpw     perpw            s            s
# 2          dirpw     dirpw  Degree true  Degree true
# 3           shww      shww            m            m
# 4           mpww      mpww            s            s
# 5          wvdir     wvdir  Degree true  Degree true
# 6             ws        ws      m s**-1      m s**-1
# 7           wdir      wdir  Degree true  Degree true
# 8          swell     swell            m            m
# 9          swell     swell            m            m
# 10         swper     swper            s            s
# 11         swper     swper            s            s
#
#                                              nameECMF  \
# 0   Significant height of combined wind waves and ...
# 1                            Primary wave mean period
# 2                              Primary wave direction
# 3                    Significant height of wind waves
# 4                           Mean period of wind waves
# 5                             Direction of wind waves
# 6                                          Wind speed
# 7                                      Wind direction
# 8                   Significant height of swell waves
# 9                   Significant height of swell waves
# 10                         Mean period of swell waves
# 11                         Mean period of swell waves
#
#                                                  name cfVarNameECMF cfVarName  \
# 0   Significant height of combined wind waves and ...           swh       swh
# 1                            Primary wave mean period         perpw     perpw
# 2                              Primary wave direction         dirpw     dirpw
# 3                    Significant height of wind waves          shww      shww
# 4                           Mean period of wind waves          mpww      mpww
# 5                             Direction of wind waves         wvdir     wvdir
# 6                                          Wind speed            ws        ws
# 7                                      Wind direction          wdir      wdir
# 8                   Significant height of swell waves         swell     swell
# 9                   Significant height of swell waves         swell     swell
# 10                         Mean period of swell waves         swper     swper
# 11                         Mean period of swell waves         swper     swper
#
#    ifsParam                       md5Section4  \
# 0    140229  c170a6a0f6947e40e0918d0005d86a05
# 1    260234  508ae75c89632a58aafcf320fa5d7cce
# 2    260233  a699647723b4977698ec02fa531d7d86
# 3    140234  78303d876e673a20bf7b022fa53411dd
# 4    140236  28097d666f05648abf7ba05e33fdac23
# 5    260232  d82bc26d67961c4aef40b644c0566def
# 6        10  33d903c1e2b696e5ce21d6cd5f8847b3
# 7      3031  c8c6287ee1daa39f2aba7e9f59924a16
# 8      3105  d7f3937eede04f0767f06e525767d4ae
# 9      3105  d7f3937eede04f0767f06e525767d4ae
# 10     3106  be154367cd7f73f4f5737e78bd1283b1
# 11     3106  be154367cd7f73f4f5737e78bd1283b1
#
#                           md5Headers numberOfValues referenceValue  \
# 0   fe9540cc9e4924cae6fe71d19869eeae         577068            0.0
# 1   c31d1401bec5593fd85fef2524774cfc         577008            5.0
# 2   66a064dbc4d8e443c3ce87b3f170b27f         576988            2.0
# 3   8e52900cc287b1a03b8d114a5791b279         503202            0.0
# 4   67f0b4f2730784489a3343ca30a59c85         503202            4.0
# 5   bee70366e14fd8f8386bad02208c71ff         503202            0.0
# 6   8fa587c73dfd089308cd2fcebb408646         577092           71.0
# 7   1ac3634240ba81d53858af4ad7a1ab6d         577092          427.0
# 8   b8e69ae1cbcec171d14a24f6eabb6166         572257            0.0
# 9   b8e69ae1cbcec171d14a24f6eabb6166         557362            0.0
# 10  1c14423e2a7749b49ad6c50e2e85b1d5         572257            4.0
# 11  1c14423e2a7749b49ad6c50e2e85b1d5         557362            5.0
#
#    referenceValueError bitsPerValue                       md5Section5  \
# 0                  0.0           11  b05b0f4fb6c673dd27d1e5b811ebc26a
# 1                  0.0           12  ae23e7b83f08da0a9ee77b69d679a2fe
# 2                  0.0           16  24b5c5062b047e5bd02a431aeceb2747
# 3                  0.0           11  79def9a4d0c25c8db9542d3fdba1a069
# 4                  0.0           11  1ab521e6a9fb7bedc3cf1a7a4482d5a0
# 5                  0.0           16  4ef074580e562b9fe402bdf55ef39b3c
# 6             0.000008           12  328013811c419500ae6e79ca8c438cb2
# 7             0.000031           16  64b32882d42412d599b538d89ae63a79
# 8                  0.0           10  836d2ca088a51ac9ec79a39d9184c047
# 9                  0.0            9  8eae403ce8940340e1ea324600cbb3f5
# 10                 0.0           11  89ad4283140b71ab89d789a4a980aabd
# 11                 0.0           12  d4c62ef34ea525cc1349bcd8d3f6aa21
#
#                          md5Section6 section7Length maximum minimum  \
# 0   c2579f26d05124c23a1c01299ea80e67         241200    12.3     0.0
# 1   2b0369ef719bbea462d0284bf815d303         374239   21.37    0.05
# 2   53974b90da627b70a25915ad723c3d11         717452  359.41    0.02
# 3   6096c1e24fe5df3564368aadce93e0f6         348619    12.3     0.0
# 4   6096c1e24fe5df3564368aadce93e0f6         483817    18.6    0.04
# 5   6096c1e24fe5df3564368aadce93e0f6         788009  358.54     0.0
# 6   49d07b23f46f472d283ed9301db1e0fc         436979   28.08    0.71
# 7   49d07b23f46f472d283ed9301db1e0fc         761715  355.96    4.27
# 8   206a8d1bc3f0333ffbf25846529a96a9         331578    7.86     0.0
# 9   3e3c0b04192b04524b7e800cc7e41ab7         293711    3.91     0.0
# 10  206a8d1bc3f0333ffbf25846529a96a9         478789   19.12    0.04
# 11  3e3c0b04192b04524b7e800cc7e41ab7         560408   21.42    0.05
#
#        average standardDeviation  skewness  kurtosis numberOfMissing  \
# 0      2.66111          1.379419  1.591432  4.265451          461172
# 1    11.680495          2.790514 -0.537673    0.4185          461232
# 2   222.368391         88.614041 -0.792246   -0.2693          461252
# 3     1.487153          1.558553  1.981234   5.30787          535038
# 4     5.275471          3.345633  0.320287 -0.514207          535038
# 5   123.643278         98.154982  0.579994 -0.981377          535038
# 6     7.728259          3.779088  0.916043  1.023972          461148
# 7   180.777148         91.831834 -0.005455 -1.318091          461148
# 8     1.535841          0.953405  1.265929   1.94028          465983
# 9     0.695237          0.393249    0.8518  1.969178          480878
# 10    11.29186          2.698975 -1.115965  2.393871          465983
# 11   10.706861          3.524854  -0.64039   1.05621          480878
#
#    setBitsPerValue                       md5Section7
# 0               11  cbb038275f8cdd63cc021200b2c059db
# 1               12  2b90b50f52357e87b55154ce0a65d5ec
# 2               16  92b72e4781c78bc9fe136b985b2a0ef5
# 3               11  26bbe19c1ad4565aaaf0dab58b0db591
# 4               11  bb8e68d7f615e28f25fed2cbd39f3e1c
# 5               16  11942867fb7fd25b37d96b2f136381e6
# 6               12  44050961370d115c8527cabece2f7acb
# 7               16  defc5ba5850b907ada591a965a923bae
# 8               10  38cafc511d77c7426eb4d84282b3517c
# 9                9  ba63305d627b713a866864fffb0a97e5
# 10              11  050495f3405feefa89c984a2618fd959
# 11              12  043e31e792882075d8732262d25ed6cd
#
# ***********************************************************

# %%
grbs = open_grib(gribfile)
grb = filter_grib_layers(grbs, shortName='swh')
# Out:
# After filterings still 1 grib messages left.

# %%
grb
# Out:
# 1:Significant height of combined wind waves and swell:m (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 202401280000:ens mean

# %%
values, lats, longs = grib_message_to_arrays_raster(grb)

# %%
values, lats, longs
# Out:
# (masked_array(
#    data=[[--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --],
#          ...,
#          [--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --]],
#    mask=[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#    fill_value=9999.0),
#  array([[ 90.  ,  90.  ,  90.  , ...,  90.  ,  90.  ,  90.  ],
#         [ 89.75,  89.75,  89.75, ...,  89.75,  89.75,  89.75],
#         [ 89.5 ,  89.5 ,  89.5 , ...,  89.5 ,  89.5 ,  89.5 ],
#         ...,
#         [-89.5 , -89.5 , -89.5 , ..., -89.5 , -89.5 , -89.5 ],
#         [-89.75, -89.75, -89.75, ..., -89.75, -89.75, -89.75],
#         [-90.  , -90.  , -90.  , ..., -90.  , -90.  , -90.  ]]),
#  array([[0.00000000e+00, 2.50000011e-01, 5.00000022e-01, ...,
#          3.59250016e+02, 3.59500016e+02, 3.59750016e+02],
#         [0.00000000e+00, 2.50000011e-01, 5.00000022e-01, ...,
#          3.59250016e+02, 3.59500016e+02, 3.59750016e+02],
#         [0.00000000e+00, 2.50000011e-01, 5.00000022e-01, ...,
#          3.59250016e+02, 3.59500016e+02, 3.59750016e+02],
#         ...,
#         [0.00000000e+00, 2.50000011e-01, 5.00000022e-01, ...,
#          3.59250016e+02, 3.59500016e+02, 3.59750016e+02],
#         [0.00000000e+00, 2.50000011e-01, 5.00000022e-01, ...,
#          3.59250016e+02, 3.59500016e+02, 3.59750016e+02],
#         [0.00000000e+00, 2.50000011e-01, 5.00000022e-01, ...,
#          3.59250016e+02, 3.59500016e+02, 3.59750016e+02]]))

# %%
gdas_url = "https://nomads.ncep.noaa.gov/pub/data/nccf/com/gfs/prod/gdas.20240129/00/wave/gridded/"
target = "gdaswave.t00z.atlocn.0p16.f001.grib2"

# %%
write_response(gdas_url, target)
# Out:
# gdaswave.t00z.atlocn.0p16.f001.grib2 written successfully

# %%
response = requests.get(f'{gdas_url}/{target}')
if response.status_code == 200:
    # Use a temporary file to store the response content
    with tempfile.NamedTemporaryFile() as tmp:
        tmp.write(response.content)
        tmp.flush()

        # Open the dataset from the temporary file
        with xr.open_dataset(tmp.name, engine='cfgrib') as ds:
            # Extract the necessary data here
            test_dataset = ds.load()  # 'load' will load the data into memory
else:
    print(f"Failed to get data: {response.status_code}")

# %%
test_dataset
# Out:
# <xarray.Dataset>
# Dimensions:              (latitude: 331, longitude: 301, orderedSequenceData: 3)
# Coordinates:
#     time                 datetime64[ns] 2024-01-29
#     step                 timedelta64[ns] 01:00:00
#     surface              float64 1.0
#   * latitude             (latitude) float64 55.0 54.83 54.67 ... 0.1666 0.0
#   * longitude            (longitude) float64 260.0 260.2 260.3 ... 309.8 310.0
#     valid_time           datetime64[ns] 2024-01-29T01:00:00
#   * orderedSequenceData  (orderedSequenceData) float64 1.0 2.0 3.0
# Data variables: (12/13)
#     ws                   (latitude, longitude) float32 nan nan nan ... nan nan
#     wdir                 (latitude, longitude) float32 nan nan nan ... nan nan
#     u                    (latitude, longitude) float32 nan nan nan ... nan nan
#     v                    (latitude, longitude) float32 nan nan nan ... nan nan
#     swh                  (latitude, longitude) float32 nan nan nan ... nan nan
#     perpw                (latitude, longitude) float32 nan nan nan ... nan nan
#     ...                   ...
#     shww                 (latitude, longitude) float32 nan nan nan ... nan nan
#     swell                (orderedSequenceData, latitude, longitude) float32 n...
#     mpww                 (latitude, longitude) float32 nan nan nan ... nan nan
#     swper                (orderedSequenceData, latitude, longitude) float32 n...
#     wvdir                (latitude, longitude) float32 nan nan nan ... nan nan
#     swdir                (orderedSequenceData, latitude, longitude) float32 n...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2024-01-29T08:14 GRIB to CDM+CF via cfgrib-0.9.1...
